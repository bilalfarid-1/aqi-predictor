# %% [markdown]
# # 🍃 Exploratory Data Analysis: Pearls AQI Predictor
# **10Pearls Shine Internship Cohort 9 — Data Science**
#
# This notebook performs deep exploratory analysis on air quality indices, pollutant distributions (PM2.5, PM10, NO2, SO2, CO, O3), and atmospheric weather signals.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve().parent))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.data_ingestion import fetch_historical_archive
from src.feature_engineering import create_features

plt.style.use('seaborn-v0_8-whitegrid')
print('Libraries loaded successfully!')

# %% [markdown]
# ### 1. Ingest Data for Analysis (Lahore & Karachi)

# %%
df_raw = fetch_historical_archive(city='Lahore', start_date='2025-01-01')
print(f'Raw dataset shape: {df_raw.shape}')
df_raw.head()

# %% [markdown]
# ### 2. Summary Statistics & Missing Values

# %%
print(df_raw.info())
display(df_raw.describe().T)

# %% [markdown]
# ### 3. Correlation Heatmap between Pollutants & Weather Factors

# %%
numeric_df = df_raw.select_dtypes(include=[np.number])
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, fmt='.2f', cmap='coolwarm', cbar=True)
plt.title('Correlation Matrix: Pollutants vs Weather Signals')
plt.show()
